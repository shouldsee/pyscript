# %%
import math
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from functools import reduce

# %%
def get_factorial(n):
	if n<0 or int(n)!=n:
		print("factorial input invalid");
		
	facts=range(1,n+1);
	if not facts:
		nfact=1;
	else:
		nfact=reduce( lambda x,y:x*y, facts);
	return nfact;


def taylor_expansion_exp(dt,n):
	term=dt**n/get_factorial(n)
	return term

# now write function that sums a set of terms (i=0 to i=n)

def sum_taylor_expansion_exp(dt, max_n):
	summed_terms=0
	for ni in range(0, max_n+1):
		summed_terms+=taylor_expansion_exp(dt,ni)
	return summed_terms

# now write master function to plot Taylor approximation

# MASTER FUNCTION

def plot_taylor_approximation_exp(n, tmax,plot=False):

	# plot the taylor expansion of the exponential function up to term n
	#
	# showComponents = True or False
	# turn on/off additional plot of each term in the series
	#
	# showError = True / False
	# turn on/off additional plot showing relative error


    tmin=0
    tmax=tmax

    dt=np.linspace(tmin,tmax,400)

    t=[]
    y_taylor=[]
    y_exact=[]

    for dti in dt:
        yi_taylor = sum_taylor_expansion_exp(dti,n)
        yi_exact=math.exp(dti)
        t.append(dti)
        y_taylor.append(yi_taylor)
        y_exact.append(yi_exact)

    plt.close("all")
    fig=plt.figure(figsize=[6,10])
    ax=fig.add_subplot(3,1,1)
    ax.set_title("Plot of Taylor approximation (Exact function shown as dashed line)",fontsize='small')
    ax.plot(t,y_exact,'-k',ls='dashed',label="y=e^t")
    ax.plot(t,y_taylor,'-r',label="taylor approx to term {}".format(n))
    ax.set_xlim([tmin,tmax])
    ax.set_ylim([0,1.1*math.exp(tmax)])
    ax.legend(loc='lower right',fontsize='small')

    ax2=fig.add_subplot(3,1,2)
    ax2.set_title("Components of Taylor series",fontsize='small')
    components={}
    for i in range(n+1):
        components[i]=[]
    for dti in dt:
        for i in range(n+1):
            components[i].append(   taylor_expansion_exp(dti,i) )
    for i in range(n+1):
        ax2.plot(t,components[i],ls='dotted',label="{}th term".format(i))
    
    ax2.set_ylim([0,1.2])
    ax2.legend(loc='upper left',fontsize='small')
    ax3=fig.add_subplot(3,1,3)
    ax3.set_title("Plot of relative error (line is 1% level)",fontsize='small')
    rel_error=[]
    for i in range(0,len(t)):
        rel_error.append((y_exact[i]-y_taylor[i])/y_exact[i])
    # (rel_error.append((y_exact[i]-y_taylor[i])/y_exact[i]) for i in range(0,len(t)));
#     if plot:
    ax3.plot(t,rel_error,label="rel err".format(n))
    ax3.set_ylim([0,0.1])
    ax3.plot([0,tmax],[0.01,0.01],ls='dotted',label="1% error")
    ax3.legend(loc='upper left',fontsize='small')
    minsep=min((abs(x-0.01) for x in rel_error));
    tcrit=t[next(i for i,x in enumerate(rel_error) if abs(x-0.01)==minsep)];
    print("accurate to 1% until time %.3f",tcrit)
#     fig.show()
    if not plot:
        plt.close("all");
    
    
# code to call master function

# %%
plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-88d627f14d84> in <module>()
# ----> 1 plot
#
# NameError: name 'plot' is not defined

# %%
n=3;
# tmax=1.5;
for n in range(5+1):
    plot_taylor_approximation_exp(n=n, tmax=3)
# Out:
# accurate to 1% until time %.3f 0.00751879699248
# accurate to 1% until time %.3f 0.15037593985
# accurate to 1% until time %.3f 0.436090225564
# accurate to 1% until time %.3f 0.81954887218
# accurate to 1% until time %.3f 1.27819548872
# accurate to 1% until time %.3f 1.78195488722

# %%
from matplotlib import pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches
import numpy as np
import math
# %matplotlib inline

# %%
# -*- coding: utf-8 -*-
from matplotlib import pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches
import numpy as np
import math

#####################################################
#
# INFORMATION
#
# The code below allows us to integrate
# dy/dt = t^3 - 1.5t^2 + 4
#
# It also display the results on a graph as the area
# under the integrated curve
#
######################################################


# def dydt(t):
# 	return  t**3 - 3*t**2/2 + 4.

# def y(t):
# 	return (t**4)/4 - (t**3)/2 + 4*t + 20

def area_of_strip_under_dydt(t_start,width):
	area=dydt(t_start)*width
	return area

def area_of_trapezium_under_dydt(t_start,width):
	t_end=t_start+width
	area=0.5 * ( dydt(t_start)+dydt(t_end) )*width
	return area

def sum_strips(t_start, t_end, n_strips):
	interval=t_end-t_start
	width=interval/n_strips
	total_area=0
	for i in range(n_strips):
		strip_start=t_start+ i *width
		total_area+=area_of_strip_under_dydt(strip_start,width)
	return total_area

def sum_trapezium_strips(t_start, t_end, n_strips):
	interval=t_end-t_start
	width=interval/n_strips
	total_area=0
	for i in range(n_strips):
		strip_start=t_start+ i *width
		total_area+=area_of_trapezium_under_dydt(strip_start,width)
	return total_area

def draw_trapezium(ax,x0,x1,y0,y1,y2,mycolor='blue'):
	verts = [
		(x0, y0), # left, bottom
		(x0, y1), # left, top
		(x1, y2), # right, top
		(x1, y0), # right, bottom
		(0., 0.), # ignored
	]

	codes = [Path.MOVETO,
		 Path.LINETO,
		 Path.LINETO,
		 Path.LINETO,
		 Path.CLOSEPOLY,
		 ]

	path = Path(verts, codes)

	patch = patches.PathPatch(path, facecolor='none',alpha=0.6,edgecolor=mycolor,ls='solid',lw=2)
	ax.add_patch(patch)

def draw_rectangle(ax,x0,x1,y0,y1,mycolor='green'):
	draw_trapezium(ax,x0,x1,y0,y1,y1,mycolor)

def draw_trapezium_strips(t_start, t_end, n_strips,ax):
	interval=t_end-t_start
	width=interval/n_strips
	total_area=0
	for i in range(n_strips):
		strip_start=t_start+ i *width
		strip_end=strip_start+width
		draw_trapezium(ax,strip_start,strip_end,0,dydt(strip_start),dydt(strip_end))
	return True

def draw_rectangular_strips(t_start, t_end, n_strips,ax):
	interval=t_end-t_start
	width=interval/n_strips
	total_area=0
	for i in range(n_strips):
		strip_start=t_start+ i *width
		strip_end=strip_start+width
		draw_rectangle(ax,strip_start,strip_end,0,dydt(strip_start))
	return True


#########################################
#
# You can change the parameters used
# for integration below.
#


def dydt(t):
	return  t**3 - 3*t**2/2 + 4.

def y(t):
	return (t**4)/4 - (t**3)/2 + 4*t + 20


n_strips = 5
t_start = 0.0
t_end = 3.0

# If you need to change the y-axis limits change the lines below
#
y_axis_min = 0
y_axis_max = 20


##########################################
# DO NOT CHANGE THE CODE BELOW HERE....
##########################################

intg_exact=y(t_end) - y(t_start);
print ("The exact value of the integral is:")
print (intg_exact)

for n_strips in range(4,114):
    intg_appx=sum_trapezium_strips(t_start,t_end,n_strips);
#     print ("Using {} rectangles to approximate the area we calculate the integral as:".format(n_strips))
    print ("{} rectangles give area of {:.3f}".format(n_strips,intg_appx), "with the error being {}%".format((intg_appx-intg_exact)/intg_exact*100))





#print "Using {} trapezoids to approximate the area we calculate the integral as:".format(n_strips)
#print sum_trapezium_strips(t_start,t_end,n_strips)

# COD TO DRAW FIGURE SHOWING STRIPS METHOD
plt.close("all")
fig=plt.figure(figsize=[10,6])

t_full=np.linspace(t_start-1.,t_end+1.,1000)
y_full=[]

dydt_full=[]
t_shaded=[]
dydt_shaded=[]

for ti in t_full:
	dydt_i=dydt(ti)
	dydt_full.append(dydt_i)
	y_full.append(y(ti))
	if t_start <= ti <= t_end:
		t_shaded.append(ti)
		dydt_shaded.append(dydt_i)

ax=fig.add_subplot(1,1,1)
ax.plot(t_full,dydt_full,ls='dotted')
ax.fill_between(t_sbhaded,dydt_shaded,alpha=0.2)
ax.text(-0.5,10,"Numerical intergration to \nestimate area under curve of \ny'(t) = t^3 - 3*t^2/2 + 4")

# draw_rectangular_strips(t_start,t_end,n_strips,ax)
draw_trapezium_strips(t_start,t_end,n_strips,ax)

ax.set_ylim(0,y_axis_max)
ax.set_ylabel("dy/dt")
# plt.close("all")
# plt.show("all")
fig.show()
# Out:
# The exact value of the integral is:
# 18.75
# 4 rectangles give area of 19.594 with the error being 4.5%
# 5 rectangles give area of 19.290 with the error being 2.8799999999999955%
# 6 rectangles give area of 19.125 with the error being 2.0%
# 7 rectangles give area of 19.026 with the error being 1.4693877551020098%
# 8 rectangles give area of 18.961 with the error being 1.125%
# 9 rectangles give area of 18.917 with the error being 0.8888888888888762%
# 10 rectangles give area of 18.885 with the error being 0.7199999999999894%
# 11 rectangles give area of 18.862 with the error being 0.595041322314027%
# 12 rectangles give area of 18.844 with the error being 0.5%
# 13 rectangles give area of 18.830 with the error being 0.4260355029585981%
# 14 rectangles give area of 18.819 with the error being 0.36734693877552144%
# 15 rectangles give area of 18.810 with the error being 0.3200000000000311%
# 16 rectangles give area of 18.803 with the error being 0.28125%
# 17 rectangles give area of 18.797 with the error being 0.24913494809690445%
# 18 rectangles give area of 18.792 with the error being 0.2222222222222096%
# 19 rectangles give area of 18.787 with the error being 0.19944598337950006%
# 20 rectangles give area of 18.784 with the error being 0.17999999999998786%
# 21 rectangles give area of 18.781 with the error being 0.16326530612241186%
# 22 rectangles give area of 18.778 with the error being 0.14876033057847354%
# 23 rectangles give area of 18.776 with the error being 0.13610586011340806%
# 24 rectangles give area of 18.773 with the error being 0.125%
# 25 rectangles give area of 18.772 with the error being 0.11519999999999679%
# 26 rectangles give area of 18.770 with the error being 0.10650887573967792%
# 27 rectangles give area of 18.769 with the error being 0.09876543209876823%
# 28 rectangles give area of 18.767 with the error being 0.09183673469387561%
# 29 rectangles give area of 18.766 with the error being 0.0856123662306724%
# 30 rectangles give area of 18.765 with the error being 0.08000000000005987%
# 31 rectangles give area of 18.764 with the error being 0.07492195629551664%
# 32 rectangles give area of 18.763 with the error being 0.0703125%
# 33 rectangles give area of 18.762 with the error being 0.0661157024793321%
# 34 rectangles give area of 18.762 with the error being 0.06228373702424505%
# 35 rectangles give area of 18.761 with the error being 0.0587755102041001%
# 36 rectangles give area of 18.760 with the error being 0.055555555555561874%
# 37 rectangles give area of 18.760 with the error being 0.052593133674236014%
# 38 rectangles give area of 18.759 with the error being 0.049861495844879755%
# 39 rectangles give area of 18.759 with the error being 0.047337278106529844%
# 40 rectangles give area of 18.758 with the error being 0.044999999999996966%
# 41 rectangles give area of 18.758 with the error being 0.04283164782865848%
# 42 rectangles give area of 18.758 with the error being 0.040816326530602964%
# 43 rectangles give area of 18.757 with the error being 0.03893996755003097%
# 44 rectangles give area of 18.757 with the error being 0.03719008264459944%
# 45 rectangles give area of 18.757 with the error being 0.035555555555561114%
# 46 rectangles give area of 18.756 with the error being 0.03402646502835675%
# 47 rectangles give area of 18.756 with the error being 0.032593933906734186%
# 48 rectangles give area of 18.756 with the error being 0.03125%
# 49 rectangles give area of 18.756 with the error being 0.029987505206160375%
# 50 rectangles give area of 18.755 with the error being 0.028799999999970776%
# 51 rectangles give area of 18.755 with the error being 0.02768166089966447%
# 52 rectangles give area of 18.755 with the error being 0.02662721893492896%
# 53 rectangles give area of 18.755 with the error being 0.025631897472427077%
# 54 rectangles give area of 18.755 with the error being 0.02469135802467311%
# 55 rectangles give area of 18.754 with the error being 0.02380165289254895%
# 56 rectangles give area of 18.754 with the error being 0.022959183673473643%
# 57 rectangles give area of 18.754 with the error being 0.022160664819921294%
# 58 rectangles give area of 18.754 with the error being 0.021403091557658627%
# 59 rectangles give area of 18.754 with the error being 0.020683711577172897%
# 60 rectangles give area of 18.754 with the error being 0.020000000000019707%
# 61 rectangles give area of 18.754 with the error being 0.01934963719431456%
# 62 rectangles give area of 18.754 with the error being 0.018730489073846%
# 63 rectangles give area of 18.753 with the error being 0.018140589569156873%
# 64 rectangles give area of 18.753 with the error being 0.017578125%
# 65 rectangles give area of 18.753 with the error being 0.017041420118384092%
# 66 rectangles give area of 18.753 with the error being 0.016528925619809343%
# 67 rectangles give area of 18.753 with the error being 0.016039206950286673%
# 68 rectangles give area of 18.753 with the error being 0.015570934256080212%
# 69 rectangles give area of 18.753 with the error being 0.015122873345925806%
# 70 rectangles give area of 18.753 with the error being 0.014693877551015552%
# 71 rectangles give area of 18.753 with the error being 0.014282880380847018%
# 72 rectangles give area of 18.753 with the error being 0.013888888888876258%
# 73 rectangles give area of 18.753 with the error being 0.013510977669341175%
# 74 rectangles give area of 18.752 with the error being 0.013148283418577952%
# 75 rectangles give area of 18.752 with the error being 0.012799999999989117%
# 76 rectangles give area of 18.752 with the error being 0.012465373961238887%
# 77 rectangles give area of 18.752 with the error being 0.012143700455377862%
# 78 rectangles give area of 18.752 with the error being 0.011834319526637197%
# 79 rectangles give area of 18.752 with the error being 0.011536612722352402%
# 80 rectangles give area of 18.752 with the error being 0.011249999999961346%
# 81 rectangles give area of 18.752 with the error being 0.01097393689982103%
# 82 rectangles give area of 18.752 with the error being 0.010707911957145674%
# 83 rectangles give area of 18.752 with the error being 0.010451444331522453%
# 84 rectangles give area of 18.752 with the error being 0.010204081632650741%
# 85 rectangles give area of 18.752 with the error being 0.009965397923868597%
# 86 rectangles give area of 18.752 with the error being 0.009734991887512479%
# 87 rectangles give area of 18.752 with the error being 0.00951248513676243%
# 88 rectangles give area of 18.752 with the error being 0.009297520661164071%
# 89 rectangles give area of 18.752 with the error being 0.009089761393757575%
# 90 rectangles give area of 18.752 with the error being 0.0088888888889187%
# 91 rectangles give area of 18.752 with the error being 0.00869460210122952%
# 92 rectangles give area of 18.752 with the error being 0.008506616257117608%
# 93 rectangles give area of 18.752 with the error being 0.008324661810623487%
# 94 rectangles give area of 18.752 with the error being 0.008148483476607757%
# 95 rectangles give area of 18.751 with the error being 0.007977839335183035%
# 96 rectangles give area of 18.751 with the error being 0.0078125%
# 97 rectangles give area of 18.751 with the error being 0.007652247847810638%
# 98 rectangles give area of 18.751 with the error being 0.007496876301577989%
# 99 rectangles give area of 18.751 with the error being 0.007346189164347076%
# 100 rectangles give area of 18.751 with the error being 0.007199999999935851%
# 101 rectangles give area of 18.751 with the error being 0.007058131555709224%
# 102 rectangles give area of 18.751 with the error being 0.00692041522489717%
# 103 rectangles give area of 18.751 with the error being 0.0067866905458042%
# 104 rectangles give area of 18.751 with the error being 0.0066568047337227645%
# 105 rectangles give area of 18.751 with the error being 0.006530612244906328%
# 106 rectangles give area of 18.751 with the error being 0.006407974368092558%
# 107 rectangles give area of 18.751 with the error being 0.006288758843557693%
# 108 rectangles give area of 18.751 with the error being 0.0061728395061967%
# 109 rectangles give area of 18.751 with the error being 0.006060095951530305%
# 110 rectangles give area of 18.751 with the error being 0.005950413223141974%
# 111 rectangles give area of 18.751 with the error being 0.005843681519365873%
# 112 rectangles give area of 18.751 with the error being 0.005739795918335251%
# 113 rectangles give area of 18.751
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
#  with the error being 0.005638656120311225%

# %%
def dydt(ynow,r=-0.5):
	return  r*ynow
def y(t):
    return [10000*math.exp(-0.5*x) for x in t];

def march(tnow,ynow,dydt,dt):
    yout=ynow+dydt(ynow)*dt;
    tout=tnow+dt;
    return (tout,yout);
# def y(t):
# 	return (t**4)/4 - (t**3)/2 + 4*t + 20


n_strips = 5

t_start = 0.0
t_end = 3.0
dt=0.1;
# ts=np.linspace(t_start,t_end)

# If you need to change the y-axis limits change the lines below
#
y_axis_min = 0
y_axis_max = 20
y_0=10000;
t_0=0.0;
t_end=100.0;
dt=0.1;
n_steps=int((t_end-t_0)/dt);
ts=np.linspace(t_0,t_end,n_steps);

def ts2ys(ts,y_0,dydt=dydt):
    tss=[];
    yss=[];
    tnow=t_0;
    ynow=y_0;
    for t in ts:
    #     tss=tss.append(tnow);
    #     yss=yss.append(ynow);
        tss+=[tnow];
        yss+=[ynow];
        (tnow,ynow) = march(tnow,ynow,dydt,dt);
    return(tss,yss)
r=-100;
y_0=1000;
# dt=abs(0.2/r);
dt=0.2/abs(r);
n_steps=int((t_end-t_0)/dt);
ts=np.linspace(t_0,t_end,n_steps);

dydt=lambda y:r*y;
ybase=lambda t:y_0*math.exp(0.5*t);
y=lambda lst:[ybase(x) for x in lst];
(tss,yss)=ts2ys(ts,y_0,dydt);
ysse=y(tss);
print("worst error {:5.3f}%".format(100*max([abs(y-x)/x for (x,y) in zip(ysse,yss)])));
ts

plt.close("all")
fig=plt.figure(figsize=[10,6]);
y_span=max(yss)-min(yss);
y_full=[min(yss)-y_span*0.05,max(yss)+y_span*0.05];
t_span=max(tss)-min(tss);
t_full=[min(tss)-t_span*0.05,max(tss)+t_span*0.05];


ax=fig.add_subplot(1,1,1)
ax.plot(tss,yss,ls='solid');
ax.plot(tss,y(tss),ls='dotted');

# plt.close("all")


# ax.plot(t_full,dydt_full,ls='dotted')
# y_full

# %%
dt
