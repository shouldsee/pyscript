# %%
# from mpl_toolkits.mplot3d import Axes3D
from mpld3 import plugins
import mpld3
import sys
import os
sys.path.append(os.path.abspath('..'))

from mpld3 import utils
from utils import *
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
mpld3.enable_notebook()

# %%
class ClickInfo(plugins.PluginBase):
    """Plugin for getting info on click"""
    
    JAVASCRIPT = """
    mpld3.register_plugin("clickinfo", ClickInfo);
    ClickInfo.prototype = Object.create(mpld3.Plugin.prototype);
    ClickInfo.prototype.constructor = ClickInfo;
    ClickInfo.prototype.requiredProps = ["id","labels"];
    function ClickInfo(fig, props){
        mpld3.Plugin.call(this, fig, props);
    };
    
    ClickInfo.prototype.draw = function(){
        var obj = mpld3.get_element(this.props.id);
        var labels = (this.props.labels);
        obj.elements().on("mousedown",
                          function(d, i){
                          text=labels[i];
                          window.prompt("Copy to clipboard: Ctrl+C, Enter", text);
                          
                          new Clipboard('.btn', {
                            text: function(trigger) {
                                return copyThis;
                            }
                        });
                          });
    }
    """
    
#     obj.elements().on("mousedown",
#                           function(d, i){alert("clicked on points[" + labels[i] + "]");});
    def __init__(self, points,labels=None):
        self.dict_ = {"type": "clickinfo",
                      "id": utils.get_id(points),
                     "labels":labels};

# %%
# log=readcsv('log.csv',header=['1','2','3','4','5'])
import csv
# data=[[]]*5;
data=[];
with open('log.csv', 'r') as csvfile:
    spamreader = csv.reader(csvfile, delimiter='\t', quotechar='|')
    for row in (spamreader):
        data+=[row];
        
data=np.array(data);
data[0:5,:]
# Out:
# array([['0.775697', '0.115709', '100', '3e6e201b183f856d3852da6942', '5'],
#        ['0.770616', '0.122413', '100', '3c98e98c1cf9215d99020d223b', '5'],
#        ['0.780058', '0.113514', '100', '059817607a23a31a2e216ca6e4', '5'],
#        ['0.774117', '0.123120', '100', '04e9213e7ef9e0002b41336aaa', '5'],
#        ['0.779595', '0.111025', '100', '18122185e67bc5d4f9914f8b68', '5']],
#       dtype='<U26')

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
# fig=plt.figure(figsize=[10,5])
# ax=plt.subplot(axisbg='#DDDDDD',)
fig, ax = plt.subplots(subplot_kw=dict(axisbg='#DDDDDD',))
fig.set_size_inches([10,8])
ax.grid(color='white', linestyle='solid')
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.5)

N = 100
xs=data[:,0];
ys=data[:,1];
sizs=list(float(x) for x in data[:,2])
labels=list(data[:,3]);
scatter = ax.scatter(xs,
                     ys,
                     c=list( 1.*float(i)/N for i in xs),
                     s = sizs,
                     alpha=1.0,
                     label=labels,
                     cmap=plt.cm.jet)

ax.set_title("D3 Scatter Plot (with tooltips!)", size=20)
# labels = ['point {0}'.format(i + 1) for i in range(N)]
tooltip = plugins.PointLabelTooltip(scatter, labels)
plugins.connect(fig, 
                tooltip,
                plugins.Zoom(enabled=True),
                ClickInfo(scatter,labels)
               )
# plugins.connect(fig,
#                )
# Out:
# /home/shouldsee/.local/lib/python3.5/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
