# %%
from astropy.convolution import *
import sys
import os
sys.path.append(os.path.abspath('..'))
# %matplotlib notebook
# utils=os.path.abspath('..')
from utils import *
import time
from KBs import *
(HTML(tog))
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
convolve_int=lambda a,fir,method:np.around(convolve(a,fir,method)).astype(np.int);
## Using B3/S23 as example

from os import environ
try:
    query = environ['query'];
    
    familyname, input_rulestr = query.split('_');
except:
#     familynam
    query='2dntca_000000000060031c61c67f86a0';
    print('fail to fetch query, using default rule, B3/S23 \n' +
    'example query'+query);

familyname, input_rulestr = query.split('_');
# if not 'input_rulestr' in locals():
#     input_rulestr='000000000060031c61c67f86a0';
# input_rulestr
# CA_sys
# Out:
# fail to fetch query, using default rule, B3/S23
# example query2dntca_000000000060031c61c67f86a0

# %%
# @function
def measure_temperature(sys0=None,hdist=None,*args,**kwargs):
#     varargin = measure_temperature.varargin
#     nargin = measure_temperature.nargin
    sysX=copy.copy(sys0)
    jmax=sysX.N;
    avi=sysX.rdf()
    siz=avi.shape
    siz=(sysX.hmax,)+siz;
    tmp=np.zeros(siz)
    smtmp=np.zeros(siz)

    avc=avi
    i=0
    fir=np.reshape(2 ** (np.arange(0,9)),[1,3,3])
    trans=6
    mtp=0
    stp=0
    while i+1 < sysX.hmax:

        i=i + 1
        avcnew=(sysX.adv(avc,i))
        cavc=convolve_int(avc,fir,'wrap').astype(np.int);
        cavcnew=convolve_int(avcnew,fir,'wrap').astype(np.int);
        idx=np.ravel_multi_index((cavc,cavcnew),[2**9,2**9]);
        tmp[i,:,:,:]=np.expand_dims(hdist.flat[idx],0)
        if i >= trans:
            smtmpnow=np.mean(tmp[i - trans:i,:,:,:],axis=0)
            smtmp[i - trans,:,:,:]=smtmpnow
            if i >= trans + 10:
                mtp=np.mean(smtmpnow.flat)
                stpmat=((smtmp[i - trans,:,:,:] - smtmp[i - trans - trans,:,:,:]))
                a=np.mean(np.abs(stpmat.flat))
                b=abs(np.mean(stpmat.flat))
                stp=a - b
                stp1=np.mean(avcnew.flat)
                stp1=min(stp1,1 - stp1)
        avc=avcnew;
        #     im1=[avc(1,:,:)];
        if mtp < 0.02 and i > 20:
            break
    
    fam_alias=sys0.familyname+'_'+sys0.alias;
# /home/shouldsee/Documents/repos/CA_tfmat/custom_function/measure_temperature.m:55
    # s=sprintf('%s\\t%s\\t%d\\t%f\\t%f\\t%f\\n',fam_alias,num2str(sys0.od),i,mtp,stp,stp1)
    s='{}\t{}\t{:d}\t{:f}\t{:f}\t{:f}\n'.format(fam_alias,sysX.rulestr,i,mtp,stp,stp1)
# /home/shouldsee/Documents/repos/CA_tfmat/custom_function/measure_temperature.m:56
    return s
    
# if __name__ == '__main__':
#     pass

# %%
# #test
# ca1=CA_sys('2dntca',input_rulestr,[600,100,400]);
# ca1.rulestr2alias();
# s=measure_temperature(ca1,hdist);
# output_data=[];

# %%
### Profiling loop
output_data=[];
    
repeat=2;
input_list=[input_rulestr];
ipt_list=input_list*repeat;
# for i in range(5):
l_ipt=len(input_list)
log = ['Log of the process:'];
logs='Starting to profile {:d} rules at {:d} replicates,\n totaling {:d} instances'.format(l_ipt,repeat,l_ipt*repeat);
log += [logs];
# print('Starting to profile {:d} rules at {:d} replicates,\n totaling {:d} instances'.format(l_ipt,repeat,l_ipt*repeat))

for num,rulestr in enumerate(ipt_list):
    ca1=CA_sys(familyname,rulestr,[400,100,400]);
    ca1.rulestr2alias();
    s=measure_temperature(ca1,hdist);
    output_data+=[s];
#     print('{:d} of {:d}'.format(num,len(ipt_list)))
    logs =('{:d} of {:d} '.format(num,len(ipt_list)));
    log += [logs];
temp_data=[];
for line in output_data:
    temp_data+=[line.rstrip('\n').split('\t')];
sample_data=np.array(temp_data)
# print('data is succesfully generated at {:d} replicates'.format(repeat))
logs=('data is succesfully generated at {:d} replicates'.format(repeat))

log  += [logs];

# %%
# print('\n Detail of the input:')
logs='\n Detail of the input:';
log+=[logs];
for k,v in ca1.__dict__.items():
    if not callable(v):
#         print(k+str(v).ljust(-10))
#         print("{:5} {:<15} {:<10}".format('',k, str(v)))

        logs=("{:5} {:<15} {:<10}".format('',k, str(v)));
        log+=[logs];

# %%
# import numpy as np

# # TEST sample_data
# sample_data=np.array([['2dntca_b3ianjrecqyks2ac3i2e3a2k3nj2i3re2n3cqyk',
#         '000000000060031c61c67f86a0', '99', '0.148772', '0.087523',
#         '0.089563'],
#        ['2dntca_b3ianjrecqyks2ac3i2e3a2k3nj2i3re2n3cqyk',
#         '000000000060031c61c67f86a0', '99', '0.152794', '0.086693',
#         '0.091644'],
#        ['2dntca_b3ianjrecqyks2ac3i2e3a2k3nj2i3re2n3cqyk',
#         '000000000060031c61c67f86a0', '99', '0.148733', '0.089657',
#         '0.089387'],
#        ['2dntca_b3ianjrecqyks2ac3i2e3a2k3nj2i3re2n3cqyk',
#         '000000000060031c61c67f86a0', '99', '0.150105', '0.092000',
#         '0.090981'],
#        ['2dntca_b3ianjrecqyks2ac3i2e3a2k3nj2i3re2n3cqyk',
#         '000000000060031c61c67f86a0', '99', '0.153150', '0.089772',
#         '0.090938']], 
#       dtype='<U46')

# %% [markdown]
# ## Landscape of the observed dynamics
# * Hover on the point to get the NTCA(non-totalistic cellular automata) rule-string. Click to display the rulestring as a copyable string.
# * Click on the bottom-left widgets to Zoom-and-pan

# %%
# %matplotlib inline
# mpld3.enable_notebook()
from graphics import *
fig, ax = plt.subplots(subplot_kw=dict(axisbg='#DDDDDD'
#                                        ,projection='3d'
                                      ))
fig.set_size_inches([6,6])

ax.grid(color='white', linestyle='solid')
ax.set_ylim(0,0.38)
ax.set_xlim(0,1)

fig2,ax2=plt.subplots(subplot_kw=dict(axisbg='#DDDDDD'
                                       ,projection='3d'
                                      ))
fig2.set_size_inches([10,10])
# fig2.subplots_adjust(left=0.2, right=0.8, top=0.9, bottom=0.3)

ax2.grid(color='white', linestyle='solid')
ax2.set_ylim(0,0.38)
ax2.set_xlim(0,1)

fig,ax,fig2,ax2 = make_figure((fig,ax,fig2,ax2),sample_data)
fig.set_size_inches([7,7])
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el210281404032438897764541458843"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("clickinfo", ClickInfo);
#     ClickInfo.prototype = Object.create(mpld3.Plugin.prototype);
#     ClickInfo.prototype.constructor = ClickInfo;
#     ClickInfo.prototype.requiredProps = ["id","labels"];
#     function ClickInfo(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     ClickInfo.prototype.draw = function(){
#         var obj = mpld3.get_element(this.props.id);
#         var labels = (this.props.labels);
#         obj.elements().on("mousedown",
#                           function(d, i){
#                           txt=labels[i];
#                           window.prompt("You clicked Point "+ i + ", Ctrl+C to copy to clipboard, Rulestring:", txt);
#
#
#                           });
#     }
#
#        mpld3.draw_figure("fig_el210281404032438897764541458843", {"axes": [{"ydomain": [0.0, 0.38], "yscale": "linear", "sharey": [], "texts": [{"rotation": -0.0, "zorder": 3, "color": "#000000", "h_anchor": "middle", "id": "el21028140403269545152", "position": [0.5, -0.04864311315924219], "text": "Avg Temp", "coordinates": "axes", "v_baseline": "hanging", "fontsize": 15.0, "alpha": 1}, {"rotation": -90.0, "zorder": 3, "color": "#000000", "h_anchor": "middle", "id": "el21028140403269454760", "position": [-0.08000512032770096, 0.5], "text": "mean(abs(d_Temp)) - abs(mean(d_Temp))", "coordinates": "axes", "v_baseline": "auto", "fontsize": 15.0, "alpha": 1}, {"rotation": -0.0, "zorder": 3, "color": "#000000", "h_anchor": "middle", "id": "el21028140403243574272", "position": [0.5, 1.012800819252432], "text": "Dynamic landscape, 2D projection", "coordinates": "axes", "v_baseline": "auto", "fontsize": 20.0, "alpha": 1}, {"rotation": -0.0, "zorder": 1000003.0, "color": "#000000", "h_anchor": "start", "id": "el21028140403243487016", "position": [0.7515360983102921, 0.9467485919098823], "text": "Uncond_Comp", "coordinates": "axes", "v_baseline": "auto", "fontsize": 12.0, "alpha": 1}, {"rotation": -0.0, "zorder": 1000003.0, "color": "#000000", "h_anchor": "start", "id": "el21028140403243505200", "position": [0.7515360983102921, 0.8981054787506401], "text": "Cond_Comp", "coordinates": "axes", "v_baseline": "auto", "fontsize": 12.0, "alpha": 1}, {"rotation": -0.0, "zorder": 1000003.0, "color": "#000000", "h_anchor": "start", "id": "el21028140403243506880", "position": [0.7515360983102921, 0.8494623655913979], "text": "Chaos", "coordinates": "axes", "v_baseline": "auto", "fontsize": 12.0, "alpha": 1}, {"rotation": -0.0, "zorder": 1000003.0, "color": "#000000", "h_anchor": "start", "id": "el21028140403243529104", "position": [0.7515360983102921, 0.8008192524321557], "text": "sample", "coordinates": "axes", "v_baseline": "auto", "fontsize": 12.0, "alpha": 1}, {"rotation": -0.0, "zorder": 1000003.0, "color": "#000000", "h_anchor": "start", "id": "el21028140403243530896", "position": [0.7515360983102921, 0.7521761392729135], "text": "reference", "coordinates": "axes", "v_baseline": "auto", "fontsize": 12.0, "alpha": 1}], "axes": [{"grid": {"dasharray": "none", "gridOn": true, "alpha": 1.0, "color": "#FFFFFF"}, "tickvalues": null, "fontsize": 10.0, "visible": true, "position": "bottom", "tickformat": null, "nticks": 6, "scale": "linear"}, {"grid": {"dasharray": "none", "gridOn": true, "alpha": 1.0, "color": "#FFFFFF"}, "tickvalues": null, "fontsize": 10.0, "visible": true, "position": "left", "tickformat": null, "nticks": 9, "scale": "linear"}], "markers": [], "ylim": [0.0, 0.38], "paths": [{"xindex": 0, "zorder": 1000001.0, "id": "el21028140403243504640", "data": "data03", "coordinates": "axes", "pathcodes": ["M", "L", "L", "L", "Z"], "edgewidth": 1.0, "edgecolor": "#000000", "yindex": 1, "facecolor": "#008000", "dasharray": "none", "alpha": 0.5}, {"xindex": 0, "zorder": 1000001.0, "id": "el21028140403243506320", "data": "data03", "coordinates": "axes", "pathcodes": ["M", "L", "L", "L", "Z"], "edgewidth": 1.0, "edgecolor": "#000000", "yindex": 2, "facecolor": "#FFFF00", "dasharray": "none", "alpha": 0.5}, {"xindex": 0, "zorder": 1000001.0, "id": "el21028140403243528544", "data": "data03", "coordinates": "axes", "pathcodes": ["M", "L", "L", "L", "Z"], "edgewidth": 1.0, "edgecolor": "#000000", "yindex": 3, "facecolor": "#FF0000", "dasharray": "none", "alpha": 0.2}, {"xindex": 0, "zorder": 1000001.0, "id": "el21028140403243530224", "data": "data03", "coordinates": "axes", "pathcodes": ["M", "L", "L", "L", "Z"], "edgewidth": 1.0, "edgecolor": "#FF0F07", "yindex": 4, "facecolor": "#FF0F07", "dasharray": "none", "alpha": 1}, {"xindex": 0, "zorder": 1000001.0, "id": "el21028140403243531792", "data": "data03", "coordinates": "axes", "pathcodes": ["M", "L", "L", "L", "Z"], "edgewidth": 1.0, "edgecolor": "#750FFE", "yindex": 5, "facecolor": "#750FFE", "d ...

# %%
# len(ntca_list)
# .shape
# print(tst_data)
print('\n'.join(log));

# %%
# from nbconvert import HTMLExporter
# import codecs
# import nbformat
# exporter = HTMLExporter()
# # execfile()
# output_notebook = nbformat.read('calc_temp.ipynb', as_version=4)
# output, resources = exporter.from_notebook_node(output_notebook)
# codecs.open('test.html', 'w', encoding='utf-8').write(output)
